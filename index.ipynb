# %% [markdown]
# # Project: Analyzing Macbeth

# %% [markdown]
# ## Introduction
# For our first day and first data science project, we're going to do some rudimentry analysis of Shakespeare's classic play: Macbeth! You will get practice working with lists, condtionals and dictionaries, visualizing data, and thinking analytically about data.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Show mastery of the content covered in this section

# %% [markdown]
# ### Getting the Data
# Here we start by importing a python package and using it to pull the transcript of Macbeth from the project Gutenberg website. We also preview a few details about what is now stored in the variable macbeth; it's a string with 119,846 characters, the first 500 of which are printed below.

# %%
import requests
macbeth = requests.get('http://www.gutenberg.org/cache/epub/2264/pg2264.txt').text

print(type(macbeth))
print(len(macbeth))
print(macbeth[:500])
# Out:
# <class 'str'>
# 119846
# ﻿***The Project Gutenberg's Etext of Shakespeare's First Folio***
# ********************The Tragedie of Macbeth*********************
#
# This is our 3rd edition of most of these plays.  See the index.
#
#
# Copyright laws are changing all over the world, be sure to check
# the copyright laws for your country before posting these files!!
#
# Please take a look at the important information in this header.
# We encourage you to keep this file on your own disk, keeping an
# electronic path open for the nex

# %% [markdown]
# ### Your Task
#
# Your task is to create a bar graph of the 25 most common words in the Shakespeare's Macbeth.
#
#
# A common python programming pattern to counting objects, produce histograms, or update statistics is to make calls to a dictionary as you iterate through a list. For example, given a list of words, you can create a dictionary to store counts and then iterate through the list of words, checking how many times each word has appeared using your dictionary, and updating the dictionary count now that you've seen that word again. The `dictionary.get()` method is very useful in doing this. Read the docstring for the dictionary.get() method and use it along with the pseudocode above to create a bar graph of the 25 most common words from the transcript of Macbeth which has been loaded into a variable 'Macbeth'. Be sure to include a title and appropriate labels for your graph.

# %%
# Your code here

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Pseudo-code Outline
# Split the transcript into words
words = macbeth.split()
# Create a dictionary
unique_words = {}
# Iterate through the text of Macbeth

for word in words:
    if unique_words.get(word) == True:
        unique_words[word] += 1
    else:
        unique_words[word] = 1

# Update word counts
list_of_words = list(unique_words.keys())
sorted_words = list_of_words.sort()
print(list_of_words)
# x = sorted_words[-9:]
# # Create Bar Graph
# plt.bar(x)
# # Include descriptive titles and labels
# plt.title('Most Common Words in Macbeth')
# plt.xlabel('Word')
# plt.ylabel('Number of Instances')
# plt.show()
# Out:
# ['"AS-IS".', '"Defects".', '"PROJECT', '"Project', '"Project").', '"Right', '"Small', '"canon"', '"cliche".', '"errors"', '"liue"', '"not"', '"public', '"scholars"', '"small', '"v"\'s.', '"vv"', '"w"\'s,', '#2264]', '$2', '&', '&c.', "'Faith", "'Gainst", "'Tis", "'Twas", "'Twere", "'Twixt", "'boue", "'em", "'em.", "'em:", "'gainst", "'ginne", "'gins", "'tis", "'tis,", "'twer", "'twere", "'twould", '(*)', '(A', '(And', '(As,', '(Beldams)', '(CMU', '(From', '(How', '(I', '(Impostors', '(Like', '(Sir)', '(The', '(Three', '(Whereto', '(Which', '(Worthie', '(_)', '(alas)', '(and', '(as', '(at', '(if', "(if't", '(mirror', '(my', '(one', '(or', '(other', '(sharpe', '(such', '(the', '(well', '(with', '(worthy', '(~),', '***', '******', '********************The', '*****This', '***START**THE', '***The', '**Etexts', '**Information', '**Welcome', '*BEFORE!*', '*EITHER*:', '*END*THE', '*NOT*', '*These', '*WANT*', '*not*', ',', '-', '.', '.and', '.in', '.possibly', '.set', '.such', '.this', '.try', '.we', '.with', '/', '1', '1.', '1.Murth.', '10%', '100,000,000', '1971**', '1999', '2', '2.', '2.Murth.', '20%', '200', '2000', '2000+', '2001,', '2001.', '2264.txt', '2264.zip******', '2782', '3', '3,333', '3.', '30', '31,', '3rd', '432', '60', '61825', '7', '90', '<hart@pobox.com>', '=', 'A', 'ABOUT', 'ALL', 'ANY', 'ARE', 'AS', 'ASCII', 'ASCII,', 'Accents', 'According', 'Accounted', 'Accursed', 'Acheron', 'Acquaint', 'Act', 'Act,', 'Acting', 'Actions', 'Acts:', 'Actus', 'Addage', 'Adde', 'Adders', 'Adieu', 'Adieu,', 'Aduise', 'Affaire', 'Affaires', 'Affection,', 'After', 'Against', 'Agent', 'Agents', 'Ague', 'Alack,', 'Alarme', 'Alarum', "Alarum'd", 'Alarums', 'Alarums.', 'Alas', 'Aleppo', 'All', "All's", 'All.', 'All?', 'Allegeance', 'Almost', 'Alreadie', 'Already', 'Am', 'Ambition,', 'Amen', 'Amen,', 'Amen?', 'Among', 'An', 'And', 'Ang.', 'Angell', 'Angels', 'Angels,', 'Angus,', 'Angus.', 'Anon,', 'Another', 'Answer', 'Anthonies', 'Antidote', 'Antique', 'Appar.', 'Apparation,', 'Apparition,', 'Appetite,', 'Approach', 'Approch', 'Arabia', 'Are', 'Arme', 'Arme,', 'Armed', 'Armes,', 'Armor', 'Armor:', 'Armour', 'Army,', 'Aroynt', 'Art', 'Art,', 'Art.', 'Art:', 'Art?', 'Artificiall', 'As', 'Assassination', 'Assisted', 'Association', 'Association/Carnegie-Mellon', 'At', 'Attend', 'Attendants.', 'Auant,', 'Auarice', 'Auarice,', 'Auaricious,', 'Audit', 'Augures,', "Authoriz'd", 'Away', 'Away,', 'Ayre', 'Ayre,', 'Ayre-drawne-Dagger', 'Ayre:', 'Ayre;', 'BE', 'BREACH', 'BUT', 'Babe', 'Babe,', 'Babes', 'Babes,', 'Baboones', 'Baby', 'Baby-brow,', 'Backe', 'Balles,', 'Balme', 'Ban.', 'Bane,', 'Banke', 'Banners', 'Banq.', 'Banquet', 'Banquets', 'Banquo', "Banquo's", 'Banquo,', 'Banquo.', 'Banquo:', 'Banquoh?', 'Bar.', 'Barke', 'Barlet', 'Barnardo.', 'Bat', 'Bat,', 'Bath,', "Battaile's", 'Battell.', 'Battlements', 'Battlements.', 'Be', 'Beards', 'Beare,', 'Beare-like', 'Beast', 'Beauteous,', 'Bed,', "Bee't", 'Beetle,', 'Before', 'Began', 'Behold', 'Behold,', 'Being', 'Bell', 'Bell,', 'Bell-man,', 'Bell.', 'Bell:', "Bellona's", 'Belzebub?', 'Benediction.', 'Besides', 'Besides,', 'Best', 'Bestride', 'Better', 'Beware', 'Bible', 'Bill,', 'Bird', 'Bird,', 'Birds', 'Birds)', 'Birnan.', 'Birnane', 'Birth)', 'Birth-strangled', 'Birthdome:', 'Blacke', 'Blade,', 'Blanket', 'Blaspheming', 'Bleed,', 'Blesse', 'Blessing', 'Blessing,', 'Blessings', 'Blinde-wormes', 'Blood', 'Blood,', "Blood-bolter'd", 'Blood.', 'Blood:', 'Bloody', 'Bloody,', 'Blowes', 'Bond', 'Bond,', 'Bonelesse', 'Bones', 'Bonfire.', 'Booke,', 'Bosome', 'Bosomes,', 'Botches', 'Both', 'Bough,', 'Boughes.', 'Boundlesse', 'Bounty,', 'Box', 'Boy', 'Boy.', 'Boy?', 'Boyle', 'Braggart', 'Braine', 'Braine,', 'Braine?', 'Braines', "Brandish'd", 'Breach', 'Brest,', 'Brests,', 'Bridegroome,', 'Bring', 'Broke', 'Broyle,', 'Buffets', 'Building', 'Businesse', 'Businesse,', 'Businesse:', 'Businesse?', 'But', 'Butcher,', 'Buttrice,', 'By', 'Byrnam', 'Byrnan', 'Byrnane', 'Byrnane,', 'CONSEQUENTIAL,', 'CONTRACT,', 'Cae ...

# %% [markdown]
# ### Level Up (Optional)
# This project should take you about an hour and a half to complete. If you're done much more quickly than that and are not behind in the course, feel free to deepen your knowledge by completing any or all of the following tasks until you run out of time:
# * Create a list of top characters by mentions of their names
# * Split the text by which character is talking
# * Create sub graphs of the most common words by character
# * Reduce the string to the text of the play itself. (Remove any initial notes, forward, introduction, appendix, etc.)
# * Come up with some other fun analyses of the text!

# %% [markdown]
# ## Summary
# Congratulations! You've got some extra practice combining various data types into useful programming patterns and done an intitial analysis of a classic text!
